# %%
import os
import pandas as pd

# %%
# set directory
directory = 'data'

# %%
# initialize empty list
dfs = []

# initialize empty data frame
data = pd.DataFrame()

# %%
# iterate through each file and append to data frame
for filename in os.listdir(directory):
    if filename.startswith("TG_STAID"):
        filepath = os.path.join(directory, filename)
        with open(filepath, 'r') as file:
            file_content = file.read()
            temp_df = pd.read_csv(filepath, skiprows = 20)
            dfs.append(temp_df)

data = pd.concat(dfs, ignore_index=True)

# %%
# return column list
data.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
# filter and rename columns
data = data[['STAID', '    DATE', '   TG']]
data.columns = ['station_id', 'date', 'temp_c']

data
# Out:
#           station_id      date  temp_c
# 0                 71  18810101    -118
# 1                 71  18810102     -63
# 2                 71  18810103     -19
# 3                 71  18810104     -71
# 4                 71  18810105     -79
# ...              ...       ...     ...
# 15156879          97  20220527     123
# 15156880          97  20220528     116
# 15156881          97  20220529     110
# 15156882          97  20220530     108
# 15156883          97  20220531     152
#
# [15156884 rows x 3 columns]

# %%
# apply division by 10 transformation
data['temp_c'] = data['temp_c'] / 10
data
# Out:
#           station_id      date  temp_c
# 0                 71  18810101   -11.8
# 1                 71  18810102    -6.3
# 2                 71  18810103    -1.9
# 3                 71  18810104    -7.1
# 4                 71  18810105    -7.9
# ...              ...       ...     ...
# 15156879          97  20220527    12.3
# 15156880          97  20220528    11.6
# 15156881          97  20220529    11.0
# 15156882          97  20220530    10.8
# 15156883          97  20220531    15.2
#
# [15156884 rows x 3 columns]

# %%
# apply fahrenheit transformation to new column
data['temp_f'] = data['temp_c'] * (9/5) + 32
data
# Out:
#           station_id      date  temp_c  temp_f
# 0                 71  18810101   -11.8   10.76
# 1                 71  18810102    -6.3   20.66
# 2                 71  18810103    -1.9   28.58
# 3                 71  18810104    -7.1   19.22
# 4                 71  18810105    -7.9   17.78
# ...              ...       ...     ...     ...
# 15156879          97  20220527    12.3   54.14
# 15156880          97  20220528    11.6   52.88
# 15156881          97  20220529    11.0   51.80
# 15156882          97  20220530    10.8   51.44
# 15156883          97  20220531    15.2   59.36
#
# [15156884 rows x 4 columns]

# %%
# write data frame to csv file
data.to_csv('data/cleaned.csv', index = False)
