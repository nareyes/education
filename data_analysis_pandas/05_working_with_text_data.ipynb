# %%
import pandas as pd

# %% [markdown]
# # Import Data & Optimization

# %%
# import data
chicago = pd.read_csv('data/chicago.csv')
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# use info to determine memory usage
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1002.1+ KB

# %%
# identify unique values (Department is a good candidate for optimization)
chicago.nunique()
# Out:
# Name                      31776
# Position Title             1093
# Department                   35
# Employee Annual Salary     1156
# dtype: int64

# %%
# apply category optimization and display memory usage
chicago['Department'] = chicago['Department'].astype('category')
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 784.2+ KB

# %%
# identify NaN values
chicago_nan_sum = chicago.isna().sum()
chicago_nan = chicago.isna()

print(chicago_nan_sum)
print('\n')
print(chicago_nan)
# Out:
# Name                      1
# Position Title            1
# Department                1
# Employee Annual Salary    1
# dtype: int64
#
#
#         Name  Position Title  Department  Employee Annual Salary
# 0      False           False       False                   False
# 1      False           False       False                   False
# 2      False           False       False                   False
# 3      False           False       False                   False
# 4      False           False       False                   False
# ...      ...             ...         ...                     ...
# 32058  False           False       False                   False
# 32059  False           False       False                   False
# 32060  False           False       False                   False
# 32061  False           False       False                   False
# 32062   True            True        True                    True
#
# [32063 rows x 4 columns]

# %%
# drop NaN values
chicago = chicago.dropna(how = 'all')
chicago.tail()
# Out:
#                       Name                  Position Title        Department  \
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %% [markdown]
# # Common String Methods

# %%
# lower method 
# when calling string methods on series or dataframes, the method must be prefixed with .str
chicago['Name'] = chicago['Name'].str.lower()
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      aaron,  elvia j          WATER RATE TAKER       WATER MGMNT
# 1    aaron,  jeffery m            POLICE OFFICER            POLICE
# 2       aaron,  karina            POLICE OFFICER            POLICE
# 3  aaron,  kimberlei r  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  abad jr,  vicente m         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# upper method 
chicago['Name'] = chicago['Name'].str.upper()
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# title method
chicago['Name'] = chicago['Name'].str.title()
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          WATER RATE TAKER       WATER MGMNT
# 1    Aaron,  Jeffery M            POLICE OFFICER            POLICE
# 2       Aaron,  Karina            POLICE OFFICER            POLICE
# 3  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# replace method (character(s) to replace, new character(s))
chicago['Department'] = chicago['Department'].str.replace('MGMNT', 'MANAGEMENT')
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          WATER RATE TAKER  WATER MANAGEMENT
# 1    Aaron,  Jeffery M            POLICE OFFICER            POLICE
# 2       Aaron,  Karina            POLICE OFFICER            POLICE
# 3  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  Abad Jr,  Vicente M         CIVIL ENGINEER IV  WATER MANAGEMENT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# title method for remaining columns
chicago['Position Title'] = chicago['Position Title'].str.title()
chicago['Department'] = chicago['Department'].str.title()
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker  Water Management
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv  Water Management
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
# replace and astype methods to convert salary values to float
chicago['Employee Annual Salary'] = chicago['Employee Annual Salary'].str.replace('$', '').astype(float)
chicago.head()
# Out:
# C:\Users\nick.reyes\AppData\Local\Temp\ipykernel_22576\603977448.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chicago['Employee Annual Salary'] = chicago['Employee Annual Salary'].str.replace('$', '').astype(float)
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker  Water Management
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv  Water Management
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0
# 3                 89880.0
# 4                106836.0

# %%
# strip method (strips both left and right sides of blank space)
# good practice to strip all text columns in case there is accidental white space
# rstrip and lstrip remove white space from respective side, unless there is a specific use case we should use strip
chicago['Name'] = chicago['Name'].str.strip()
chicago['Position Title'] = chicago['Position Title'].str.strip()
chicago['Department'] = chicago['Department'].str.strip()

chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker  Water Management
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv  Water Management
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0
# 3                 89880.0
# 4                106836.0

# %%
# split and get method to split name
chicago['First Name'] = chicago['Name'].str.split(', ').str.get(1).str.strip().str.split(' ').str.get(0)
chicago['Middle Initial'] = chicago['Name'].str.split(', ').str.get(1).str.strip().str.split(' ').str.get(1)
chicago['Last Name'] = chicago['Name'].str.split(', ').str.get(0)

# strip new columns to ensure there is no whitespace
chicago['First Name'] = chicago['First Name'].str.strip()
chicago['Middle Initial'] = chicago['Middle Initial'].str.strip()
chicago['Last Name'] = chicago['Last Name'].str.strip()

# reorder columns
chicago = chicago.reindex(columns = ['Name', 'First Name', 'Middle Initial', 'Last Name', 'Position Title', 'Department', 'Employee Annual Salary'])

chicago.head()
# Out:
#                   Name First Name Middle Initial Last Name  \
# 0      Aaron,  Elvia J      Elvia              J     Aaron
# 1    Aaron,  Jeffery M    Jeffery              M     Aaron
# 2       Aaron,  Karina     Karina            NaN     Aaron
# 3  Aaron,  Kimberlei R  Kimberlei              R     Aaron
# 4  Abad Jr,  Vicente M    Vicente              M   Abad Jr
#
#              Position Title        Department  Employee Annual Salary
# 0          Water Rate Taker  Water Management                 90744.0
# 1            Police Officer            Police                 84450.0
# 2            Police Officer            Police                 84450.0
# 3  Chief Contract Expediter  General Services                 89880.0
# 4         Civil Engineer Iv  Water Management                106836.0

# %%
# alternate method using expand and n parameter
# expand = True returns a data frame instead of a list
# n parameter limits the amount of splits 
chicago['Position Title'].str.split(' ', expand = True, n = 1).head()
# Out:
#         0                   1
# 0   Water          Rate Taker
# 1  Police             Officer
# 2  Police             Officer
# 3   Chief  Contract Expediter
# 4   Civil         Engineer Iv

# %% [markdown]
# # Filtering w/ String Methods

# %%
# filter using contains method
# call lower method to normalize data
water_filter = chicago['Position Title'].str.lower().str.contains('water')
chicago[water_filter].head()
# Out:
#                     Name First Name Middle Initial Last Name  \
# 0        Aaron,  Elvia J      Elvia              J     Aaron
# 554   Aluise,  Vincent G    Vincent              G    Aluise
# 671      Ander,  Perry A      Perry              A     Ander
# 685  Anderson,  Andrew J     Andrew              J  Anderson
# 702    Anderson,  Donald     Donald            NaN  Anderson
#
#                                     Position Title        Department  \
# 0                                 Water Rate Taker  Water Management
# 554             Foreman Of Water Pipe Construction  Water Management
# 671                               Water Chemist Ii  Water Management
# 685  District Superintendent Of Water Distribution  Water Management
# 702             Foreman Of Water Pipe Construction  Water Management
#
#      Employee Annual Salary
# 0                   90744.0
# 554                102440.0
# 671                 82044.0
# 685                109272.0
# 702                102440.0

# %%
# filter using startswith method
water_start_filter = chicago['Position Title'].str.lower().str.startswith('water')
chicago[water_start_filter].head()
# Out:
#                     Name First Name Middle Initial Last Name  \
# 0        Aaron,  Elvia J      Elvia              J     Aaron
# 671      Ander,  Perry A      Perry              A     Ander
# 1054    Ashley,  Karma T      Karma              T    Ashley
# 1079   Atkins,  Joanna M     Joanna              M    Atkins
# 1181  Azeem,  Mohammed A   Mohammed              A     Azeem
#
#         Position Title        Department  Employee Annual Salary
# 0     Water Rate Taker  Water Management                 90744.0
# 671   Water Chemist Ii  Water Management                 82044.0
# 1054  Water Chemist Ii  Water Management                 82044.0
# 1079  Water Chemist Ii  Water Management                 82044.0
# 1181  Water Chemist Ii  Water Management                 53172.0

# %%
# filter using endswith method
ist_ends_filter = chicago['Position Title'].str.lower().str.endswith('ist')
chicago[ist_ends_filter].head()
# Out:
#                     Name First Name Middle Initial Last Name  \
# 184       Afroz,  Nayyar     Nayyar            NaN     Afroz
# 308     Alarcon,  Luis J       Luis              J   Alarcon
# 422     Allain,  Carolyn    Carolyn            NaN    Allain
# 472       Allen,  Robert     Robert            NaN     Allen
# 705  Anderson,  Edward M     Edward              M  Anderson
#
#                            Position Title             Department  \
# 184                          Psychiatrist                 Health
# 308            Loan Processing Specialist  Community Development
# 422  Senior Telecommunications Specialist                   Doit
# 472                             Machinist       Water Management
# 705             Sr Procurement Specialist            Procurement
#
#      Employee Annual Salary
# 184                 99840.0
# 308                 81948.0
# 422                 89880.0
# 472                 94328.0
# 705                 91476.0

# %% [markdown]
# # Using String Methods on Index and Column Labels

# %%
# import data with index column
chicago_indexed = pd.read_csv('data/chicago.csv', index_col = 'Name').dropna(how = 'all')
chicago_indexed.head()
# Out:
#                                Position Title        Department  \
# Name
# AARON,  ELVIA J              WATER RATE TAKER       WATER MGMNT
# AARON,  JEFFERY M              POLICE OFFICER            POLICE
# AARON,  KARINA                 POLICE OFFICER            POLICE
# AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     Employee Annual Salary
# Name
# AARON,  ELVIA J                  $90744.00
# AARON,  JEFFERY M                $84450.00
# AARON,  KARINA                   $84450.00
# AARON,  KIMBERLEI R              $89880.00
# ABAD JR,  VICENTE M             $106836.00

# %%
# output array of index labels
chicago_indexed.index
# Out:
# Index(['AARON,  ELVIA J', 'AARON,  JEFFERY M', 'AARON,  KARINA',
#        'AARON,  KIMBERLEI R', 'ABAD JR,  VICENTE M', 'ABARCA,  ANABEL',
#        'ABARCA,  EMMANUEL', 'ABASCAL,  REECE E', 'ABBASI,  CHRISTOPHER',
#        'ABBATACOLA,  ROBERT J',
#        ...
#        'ZWIT,  JEFFREY J', 'ZWOLFER,  MATTHEW W', 'ZYCH,  MATEUSZ',
#        'ZYDEK,  BRYAN', 'ZYGADLO,  JOHN P', 'ZYGADLO,  MICHAEL J',
#        'ZYGOWICZ,  PETER J', 'ZYMANTAS,  MARK E', 'ZYRKOWSKI,  CARLO E',
#        'ZYSKOWSKI,  DARIUSZ'],
#       dtype='object', name='Name', length=32062)

# %%
# strip and title on array of index labels
chicago_indexed.index = chicago_indexed.index.str.strip().str.title()
chicago_indexed.head()
# Out:
#                                Position Title        Department  \
# Name
# Aaron,  Elvia J              WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M              POLICE OFFICER            POLICE
# Aaron,  Karina                 POLICE OFFICER            POLICE
# Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     Employee Annual Salary
# Name
# Aaron,  Elvia J                  $90744.00
# Aaron,  Jeffery M                $84450.00
# Aaron,  Karina                   $84450.00
# Aaron,  Kimberlei R              $89880.00
# Abad Jr,  Vicente M             $106836.00

# %%
# upper on column labels
chicago.columns = chicago.columns.str.upper()
chicago.head()
# Out:
#                   NAME FIRST NAME MIDDLE INITIAL LAST NAME  \
# 0      Aaron,  Elvia J      Elvia              J     Aaron
# 1    Aaron,  Jeffery M    Jeffery              M     Aaron
# 2       Aaron,  Karina     Karina            NaN     Aaron
# 3  Aaron,  Kimberlei R  Kimberlei              R     Aaron
# 4  Abad Jr,  Vicente M    Vicente              M   Abad Jr
#
#              POSITION TITLE        DEPARTMENT  EMPLOYEE ANNUAL SALARY
# 0          Water Rate Taker  Water Management                 90744.0
# 1            Police Officer            Police                 84450.0
# 2            Police Officer            Police                 84450.0
# 3  Chief Contract Expediter  General Services                 89880.0
# 4         Civil Engineer Iv  Water Management                106836.0
