# %%
# import libraries
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %%
# import and inspect shape of image
camaro = io.imread("camaro.jpg")
print(camaro.shape)
# Out:
# (1200, 1600, 3)

# %%
# show image
plt.imshow(camaro)
plt.show()

# %%
# crop image
cropped = camaro[350:1100,200:1400,:]
io.imsave("camaro_cropped.jpg", cropped)
plt.imshow(cropped)
plt.show()

# %%
# flip image vertically
vertical_flip = camaro[::-1, :, :]
io.imsave("camaro_vertical_flip.jpg", vertical_flip)
plt.imshow(vertical_flip)
plt.show()

# %%
# flip image horizontally
horizontal_flip = camaro[:, ::-1, :]
io.imsave("camaro_horizontal_flip.jpg", horizontal_flip)
plt.imshow(horizontal_flip)
plt.show()

# %%
# color channels (red)
red = np.zeros(camaro.shape, dtype = "uint8")
red[:, :, 0] = camaro[:, :, 0]
io.imsave("camaro_red.jpg", red)
plt.imshow(red)
plt.show()

# %%
# color channels (green)
green = np.zeros(camaro.shape, dtype = "uint8")
green[:, :, 1] = camaro[:, :, 1]
io.imsave("camaro_green.jpg", green)
plt.imshow(green)
plt.show()

# %%
# color channels (blule)
blue = np.zeros(camaro.shape, dtype = "uint8")
blue[:, :, 2] = camaro[:, :, 2]
io.imsave("camaro_blue.jpg", blue)
plt.imshow(blue)
plt.show()
# Out:
# C:\Users\nick.reyes\AppData\Local\Temp\ipykernel_10356\1861322850.py:4: UserWarning: camaro_blue.jpg is a low contrast image
#   io.imsave("camaro_blue.jpg", blue)

# %%
# color channels (rainbow stack)
camaro_rainbow = np.vstack((red, green, blue))
io.imsave("camaro_rainbow.jpg", camaro_rainbow)
plt.imshow(camaro_rainbow)
plt.show()
